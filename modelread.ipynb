# %%
import numpy as np
import pandas as pd
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Dropout, Dense
from keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from keras.regularizers import l2
import matplotlib.pyplot as plt
from keras.preprocessing.sequence import TimeseriesGenerator
import datetime as dt
import dill
# Check current directory
import os
print(os.getcwd())
# Out:
# /Users/sethblum/Library/CloudStorage/OneDrive-MassachusettsInstituteofTechnology/Courses/1C51/project-repo/FinalProject_1.C01

# %%
strings = [
    'output_2024-05-08_19-24-19.pkl',
'output_2024-05-08_22-21-12.pkl',
'output_2024-05-09_11-42-52.pkl'
]
model = {}
history = {}
preds = {}
for string in strings:
    model[string[:-4]], history[string[:-4]], preds[string[:-4]] = dill.load(open(string, 'rb'))

# %%
history1 = model['output_2024-05-08_19-24-19']['noreg_newencodingtest_standard96newencode']
history2 = model['output_2024-05-08_22-21-12']['noreg_newencodingtest_standard96newencode']
history3 = model['output_2024-05-09_11-42-52']['noreg_newencodingtest_standard96newencode']

# %%
min(history2.history['val_mean_absolute_error'])
# Out:
# 0.11138772964477539

# %%
model4 = load_model('Model_Outputs/model_BiLSTM_3layers_2024-05-07 13:46:41.211218.keras')

# %%
print(history1.history.keys())
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
import matplotlib.pyplot as plt
n = 12
# Extract loss and MAE values from history1, history2, and history3
loss1 = history1.history['loss'][:n]
val_loss1 = history1.history['val_loss'][:n]
mae1 = history1.history['mean_absolute_error'][:n]
val_mae1 = history1.history['val_mean_absolute_error'][:n]

loss2 = history2.history['loss'][:n]
val_loss2 = history2.history['val_loss'][:n]
mae2 = history2.history['mean_absolute_error'][:n]
val_mae2 = history2.history['val_mean_absolute_error'][:n]

loss3 = history3.history['loss'][:n]
val_loss3 = history3.history['val_loss'][:n]
mae3 = history3.history['mean_absolute_error'][:n]
val_mae3 = history3.history['val_mean_absolute_error'][:n]

# Create a figure and axis objects
fig, ax1 = plt.subplots()

# Plot training and validation loss
ax1.plot(loss1, label='history1 Training Loss', c = 'r', alpha = .5)
ax1.plot(val_loss1, label='history1 Validation Loss', c = 'darkred')
ax1.plot(loss2, label='history2 Training Loss', c = 'b', alpha = .5)
ax1.plot(val_loss2, label='history2 Validation Loss', c = 'darkblue')
ax1.plot(loss3, label='history3 Training Loss', c = 'g', alpha = .5)
ax1.plot(val_loss3, label='history3 Validation Loss', c = 'darkgreen')

# Set the y-axis label for loss
ax1.set_ylabel('Loss')

# Create a secondary y-axis for MAE
# ax1 = ax1.twinx()

# Plot training and validation MAE
ax1.plot(mae1, label='history1 Training MAE', linestyle='--', c = 'r', alpha = .5)
ax1.plot(val_mae1, label='history1 Validation MAE', linestyle='--', c = 'darkred')
ax1.plot(mae2, label='history2 Training MAE', linestyle='--', c = 'b', alpha = .5)
ax1.plot(val_mae2, label='history2 Validation MAE', linestyle='--', c = 'darkblue')
ax1.plot(mae3, label='history3 Training MAE', linestyle='--', c = 'g', alpha = .5)
ax1.plot(val_mae3, label='history3 Validation MAE', linestyle='--', c = 'darkgreen')

# Set the y-axis label for MAE
ax1.set_ylabel('MAE')

# Set plot title and labels
plt.title('Training and Validation Loss and MAE')
plt.xlabel('Epochs')

# Add legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
#ax1.legend(lines + lines2, labels + labels2, loc='upper right')

# Show the plot
plt.show()

# %%
modeltest1 = history['output_2024-05-08_19-24-19']['noreg_newencodingtest_standard96newencode']
modeltest2 = history['output_2024-05-08_22-21-12']['noreg_newencodingtest_standard96newencode']
modeltest3 = history['output_2024-05-09_11-42-52']['noreg_newencodingtest_standard96newencode']

# %%
print(model4.layers[2].get_config()['layer']['config']['kernel_regularizer'])
#print(model4.layers[5].get_config())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(model4.layers[2].get_config()['layer']['config']['kernel_regularizer'])
#       2 #print(model4.layers[5].get_config())
#
# NameError: name 'model4' is not defined
