# %%
i = 1
l = []
with open('1c51_environment.yml') as file:
    for line in file:
        if (i >= 6) & (i <= 160):
            temp = line.rsplit('=', 1)
            print(temp[0])
            l.append(temp[0])
        else:
            l.append(line)
        
        i += 1

j = 1
with open('1c51_environment_rev.yml', 'w') as file:
    for line in l:
        file.write(line + '\n')
# Out:
#   - absl-py=2.1.0
#   - aiohttp=3.9.3
#   - aiosignal=1.3.1
#   - asttokens=2.4.1
#   - astunparse=1.6.3
#   - attrs=23.2.0
#   - blinker=1.7.0
#   - brotli=1.1.0
#   - brotli-bin=1.1.0
#   - brotli-python=1.1.0
#   - bzip2=1.0.8
#   - c-ares=1.27.0
#   - ca-certificates=2024.2.2
#   - cached-property=1.5.2
#   - cached_property=1.5.2
#   - cachetools=5.3.3
#   - certifi=2024.2.2
#   - cffi=1.16.0
#   - charset-normalizer=3.3.2
#   - click=8.1.7
#   - contourpy=1.2.0
#   - cryptography=42.0.5
#   - cycler=0.12.1
#   - decorator=5.1.1
#   - exceptiongroup=1.2.0
#   - executing=2.0.1
#   - flatbuffers=23.5.26
#   - fonttools=4.50.0
#   - freetype=2.12.1
#   - frozenlist=1.4.1
#   - gast=0.5.4
#   - giflib=5.2.1
#   - google-auth=2.29.0
#   - google-auth-oauthlib=1.2.0
#   - google-pasta=0.2.0
#   - grpcio=1.59.3
#   - h5py=3.10.0
#   - hdf5=1.14.3
#   - icu=73.2
#   - idna=3.6
#   - importlib-metadata=7.1.0
#   - ipython=8.22.2
#   - jedi=0.19.1
#   - joblib=1.3.2
#   - keras=2.15.0
# ...
